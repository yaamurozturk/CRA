# %%
import os
import shutil
import pandas as pd
import requests
import time
url = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/elink.fcgi?dbfrom=pubmed&linkname=pubmed_pubmed_citedin&id=22407813"
pmid = '22407813'

# %%
def download_pmc_xml(pmid):
    url = f"https://eutils.ncbi.nlm.nih.gov/entrez/eutils/elink.fcgi?dbfrom=pubmed&linkname=pubmed_pubmed_citedin&id={pmid}&rettype=xml"
    response = requests.get(url, timeout=30)
    if response.status_code == 200:
       
        file_path = f"{pmid}.xml"
        with open("citing_xml", "wb") as f:
            f.write(response.content)  # Save response XML
        print(f" File downloaded")
        return  # Exit function if successful

    #  Handle Other Errors 
    print(f" Failed ... (Status {response.status_code})")
download_pmc_xml(pmid)
xml_file = 'citing_xml'
# Out:
#  File downloaded

# %%
import lxml.etree as ET

pmids = []

def extract_pmids(xml_file):
    tree = ET.parse(xml_file)
    root = tree.getroot()
    #print(root.findall(".//Link"))
    for link in root.findall(".//Link"):
        text = " ".join(link.itertext()).strip()
        pmids.append(text)
extract_pmids(xml_file)      
print(len(pmids), pmids)
# Out:
# 64 ['39275059', '38981955', '38622137', '38497004', '38474532', '38076646', '37214711', '37034382', '36979588', '36737845', '36536633', '36475576', '36316402', '36133414', '36132507', '35558776', '35542809', '35541833', '35529211', '35520477', '35514886', '35497143', '35494640', '35424689', '35335711', '34838374', '34377553', '34067118', '34065804', '33803897', '33291853', '33244465', '32688287', '32328432', '32208468', '32195453', '31938900', '31652527', '31459247', '31458732', '31457796', '31410663', '31199142', '31129736', '31038938', '30612201', '30572668', '30460280', '30343449', '29349585', '29269774', '28724997', '28717465', '28605883', '28458628', '28134510', '27830733', '27818705', '27752120', '27266447', '25346649', '24389590', '24121717', '23502324']

# %%
import time
import requests
import pandas as pd
from concurrent.futures import ThreadPoolExecutor

BASE_URL = "https://www.ncbi.nlm.nih.gov/pmc/utils/idconv/v1.0/"

def fetch_doi(batch):
    params = {'format': 'json', 'ids': ','.join(batch),}
    try:
        response = requests.get(BASE_URL, params=params, timeout=10)
        if response.status_code == 200:
            data = response.json()
            return [(rec.get('doi', 'No full text available'), rec.get('pmid', 'Not Found'))
                    for rec in data.get('records', [])]
        elif response.status_code == 429:
            print("Rate limit exceeded! Retrying after 10 seconds...")
            time.sleep(10)
            return fetch_ids_batch(doi_batch)  # Retry the same batch
    except requests.RequestException as e:
        print(f"Request failed: {e}")

    # Return errors if request fails
    return [(doi, 'Error', 'Error') for doi in doi_batch]


batch_size = 3
nb_workers = 1
results = []

batches = [pmids[i:i + batch_size] for i in range(0, len(pmids), batch_size)]

with ThreadPoolExecutor(max_workers = nb_workers) as executor:
    results_list = list(executor.map(fetch_doi, batches)) # This returns a list of lists (batches) of tuples

# Flatten results (since each batch returns a list)
results = [item for sublist in results_list for item in sublist] # This is a list of tuples after flattening the batches lists

# Convert results to DataFrame and save as CSV
result_df = pd.DataFrame(results, columns=['DOI', 'PMID'])
display(result_df)
result_df.to_csv('citing_dois.tsv', index=False, sep='\t')
# Out:
#                                 DOI      PMID
# 0        10.1038/s41467-024-47549-1  38622137
# 1         10.3390/molecules29174211  39275059
# 2            No full text available  38981955
# 3   10.1016/j.bioactmat.2023.10.025  38076646
# 4         10.3390/molecules29051020  38474532
# ..                              ...       ...
# 59     10.1016/j.nantod.2016.05.010  27818705
# 60                10.1038/srep02933  24121717
# 61                10.1038/srep03564  24389590
# 62          10.1186/1556-276X-9-583  25346649
# 63                10.1038/srep01473  23502324
#
# [64 rows x 2 columns]

# %%
def fetch_doi(pmid):
    params = {'format': 'json', 'ids': pmid,}
    try:
        response = requests.get(BASE_URL, params=params, timeout=10)
        if response.status_code == 200:
            data = response.json()
            print(data)
            rec = data.get('records', [])
            print(rec)
            return [(rec.get('doi', 'Not Found'))
                    for rec in data.get('records', [])]
        elif response.status_code == 429:
            print("Rate limit exceeded! Retrying after 10 seconds...")
            time.sleep(10)
            return fetch_ids_batch(doi_batch)  # Retry the same batch
    except requests.RequestException as e:
        print(f"Request failed: {e}")

    # Return errors if request fails
    return [(doi, 'Error', 'Error') for doi in doi_batch]
print(fetch_doi('15369599')[0])

# %%
print(results)

# %%
## useful list of Entrez databases that can be queried through API
# pmc_pubmed	PubMed citations for these articles
# pmc_refs_pubmed	PubMed article citing PMC article
# pmc_pmc_cites	   PMC articles that given PMC article cites
# pmc_pmc_citedby	PMC article citing given PMC article
# pubmed_pubmed	 Calculated set of PubMed citations similar to the selected article(s) retrieved using a word weight algorithm. 
# pubmed_pubmed_refs    Citation referenced in PubMed article. Only valid for PubMed citations that are also in PMC.


from Bio import Entrez

Entrez.email = "mcfrank@stanford.edu"

def get_abstract(pmid):
    handle = Entrez.efetch(db='pubmed', id=pmid, retmode='text', rettype='abstract')
    return handle.read()

def get_links_id(pmid):
	link_list = []
	links = Entrez.elink(dbfrom="pubmed", id=pmid, linkname="pubmed_pubmed")	
	record = Entrez.read(links)
	
	records = record[0][u'LinkSetDb'][0][u'Link']

	for link in records:
		link_list.append(link[u'Id'])

	return link_list

def get_links_term(term):
	links = Entrez.esearch(db="pubmed", retmax = 1000, term=term)	
	record = Entrez.read(links)
	link_list = record[u'IdList']

	return link_list


### MAIN -----------------------

#print(get_links_term("Saffran JR[Author] "))

#print ("----------------------------")

#print(get_abstract("22407813"))

#print ("----------------------------")

#print(get_links_id("22407813"))

# %%
import time
from habanero import Crossref
import requests

cr = Crossref(mailto="recheinje@gmail.com", timeout=60)

def fetch_crossref_data(doi, retries=3):
    attempt = 0
    while attempt < retries:
        try:
            work = cr.works(ids=doi)
            #print('this is work ',work)
            if "message" not in work:
                print("No data found for DOI.")
                return

            message = work["message"]
            #print('this is message ', message)

            # Extract metadata
            title = message.get("title", ["No title found"])[0]
            '''license_url = None
            if "license" in message:
                license_url = message["license"][0].get("URL")'''
            
            # Extract full-text URLs for text-mining
            links = message.get("link", [])
            text_mining_links = {}
            for link in links:
                if link.get("intended-application") == "text-mining":
                    content_type = link.get("content-type")
                    url = link.get("URL")
                    text_mining_links[content_type] = url
            
            # Output
            print(f"Title: {title}")
            #print(f"License URL: {license_url}")
            print("Text-Mining URLs:")
            for k, v in text_mining_links.items():
                print(f"{k}: {v}")

            return {
                "title": title,
               # "license_url": license_url,
                "text_mining_links": text_mining_links
            }
        
        except requests.exceptions.Timeout:
            print(f"Timeout occurred. Retrying... ({attempt+1}/{retries})")
            attempt += 1
            time.sleep(2)  # wait before retrying
        except Exception as e:
            print(f"Error: {str(e)}")
            break

            
my_df = pd.read_csv('citing_dois.tsv', sep = '\t', dtype=str)
dois = my_df['DOI']


with open("file.txt", "a") as f:
    for d in dois:
        f.write('DOI: ' + d + '\n')
        print('DOI: ', d)
        
        result = fetch_crossref_data(d)
        if result is not None:
            title = result["title"]
            text_mining_links = result["text_mining_links"]
            
            print(title)
            print(text_mining_links)
            
            f.write(title + '\n')
            for content_type, url in text_mining_links.items():
                f.write(f"{content_type}: {url}\n")
        else:
            print(f"Warning: No data found for DOI {d}")
            f.write("No data found for this DOI\n")
# Out:
# DOI:  10.1038/s41467-024-47549-1
# Title: Alkyne-tagged SERS nanoprobe for understanding Cu+ and Cu2+ conversion in cuproptosis processes
# Text-Mining URLs:
# application/pdf: https://www.nature.com/articles/s41467-024-47549-1.pdf
# text/html: https://www.nature.com/articles/s41467-024-47549-1
# Alkyne-tagged SERS nanoprobe for understanding Cu+ and Cu2+ conversion in cuproptosis processes
# {'application/pdf': 'https://www.nature.com/articles/s41467-024-47549-1.pdf', 'text/html': 'https://www.nature.com/articles/s41467-024-47549-1'}
# DOI:  10.3390/molecules29174211
# Title: Carbon Dots: A Versatile Platform for Cu2+ Detection, Anti-Counterfeiting, and Bioimaging
# Text-Mining URLs:
# Carbon Dots: A Versatile Platform for Cu2+ Detection, Anti-Counterfeiting, and Bioimaging
# {}
# DOI:  No full text available
# Error: Client error '404 Not Found' for url 'https://api.crossref.org/works/No'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/404
# Warning: No data found for DOI No full text available
# DOI:  10.1016/j.bioactmat.2023.10.025
# Title: DNA tetrahedral nanostructures for the biomedical application and spatial orientation of biomolecules
# Text-Mining URLs:
# text/xml: https://api.elsevier.com/content/article/PII:S2452199X23003407?httpAccept=text/xml
# text/plain: https://api.elsevier.com/content/article/PII:S2452199X23003407?httpAccept=text/plain
# DNA tetrahedral nanostructures for the biomedical application and spatial orientation of biomolecules
# {'text/xml': 'https://api.elsevier.com/content/article/PII:S2452199X23003407?httpAccept=text/xml', 'text/plain': 'https://api.elsevier.com/content/article/PII:S2452199X23003407?httpAccept=text/plain'}
# DOI:  10.3390/molecules29051020
# Title: Construction of a New Probe Based on Copper Chaperone Protein for Detecting Cu2+ in Cells
# Text-Mining URLs:
# Construction of a New Probe Based on Copper Chaperone Protein for Detecting Cu2+ in Cells
# {}
# DOI:  10.1021/acsomega.3c07612
# Title: Carbon Dots and Their Polymeric Nanocomposites: Insight into Their Synthesis, Photoluminescence Mechanisms, and Recent Trends in Sensing Applications
# Text-Mining URLs:
# Carbon Dots and Their Polymeric Nanocomposites: Insight into Their Synthesis, Photoluminescence Mechanisms, and Recent Trends in Sensing Applications
# {}
# DOI:  10.3390/bios13030376
# Title: Wavelength-Dependent Metal-Enhanced Fluorescence Biosensors via Resonance Energy Transfer Modulation
# Text-Mining URLs:
# Wavelength-Dependent Metal-Enhanced Fluorescence Biosensors via Resonance Energy Transfer Modulation
# {}
# DOI:  10.1016/j.nantod.2022.101665
# Title: Could artificial intelligence revolutionize the development of nanovectors for gene therapy and mRNA vaccines?
# Text-Mining URLs:
# text/xml: https://api.elsevier.com/content/article/PII:S1748013222002936?httpAccept=text/xml
# text/plain: https://api.elsevier.com/content/article/PII:S1748013222002936?httpAccept=text/plain
# Could artificial intelligence revolutionize the development of nanovectors for gene therapy and mRNA vaccines?
# {'text/xml': 'https://api.elsevier.com/content/article/PII:S1748013222002936?httpAccept=text/xml', 'text/plain': 'https://api.elsevier.com/content/article/PII:S1748013222002936?httpAccept=text/plain'}
# DOI:  10.1021/acsomega.3c00873
# Title: Multifunctional Lipophobic Polymer Dots from Cyclodextrin: Antimicrobial/Anticancer Laborers and Silver Ions Chemo-Sensor
# Text-Mining URLs:
# Multifunctional Lipophobic Polymer Dots from Cyclodextrin: Antimicrobial/Anticancer Laborers and Silver Ions Chemo-Sensor
# {}
# DOI:  10.1021/acsami.2c16199
# Title: Aptamer-Functionalized Ce<sup>4+</sup>-Ion-Modified C-Dots: Peroxidase Mimicking Aptananozymes for the Oxidation of Dopamine and Cytotoxic Effects toward Cancer Cells
# Text-Mining URLs:
# Aptamer-Functionalized Ce<sup>4+</sup>-Ion-Modified C-Dots: Peroxidase Mimicking Aptananozymes for the Oxidation of Dopamine and Cytotoxic Effects toward Cancer Cells
# {}
# DOI:  10.1007/s11426-022-1408-5
# Title: Structural and functional imaging of brains
# Text-Mining URLs:
# application/pdf: https://link.springer.com/content/pdf/10.1007/s11426-022-1408-5.pdf
# text/html: https://link.springer.com/article/10.1007/s11426-022-1408-5/fulltext.html
# Structural and functional imaging of brains
# {'application/pdf': 'https://link.springer.com/content/pdf/10.1007/s11426-022-1408-5.pdf', 'text/html': 'https://link.springer.com/article/10.1007/s11426-022-1408-5/fulltext.html'}
# DOI:  10.1002/advs.202207621
# Title: Carbon Dots Based Photoinduced Reactions: Advances and Perspective
# Text-Mining URLs:
# application/pdf: https://onlinelibrary.wiley.com/doi/pdf/10.1002/advs.202207621
# application/xml: https://onlinelibrary.wiley.com/doi/full-xml/10.1002/advs.202207621
# Carbon Dots Based Photoinduced Reactions: Advances and Perspective
# {'application/pdf': 'https://onlinelibrary.wiley.com/doi/pdf/10.1002/advs.202207621', 'application/xml': 'https://onlinelibrary.wiley.com/doi/full-xml/10.1002/advs.202207621'}
# DOI:  10.1039/c9na00794f
# Title: Recent advancements in the applications of carbon nanodots: exploring the rising star of nanotechnology
# Text-Mining URLs:
# Recent advancements in the applications of carbon nanodots: exploring the rising star of nanotechnology
# {}
# DOI:  10.1039/d2na00080f
# Title: Fluorescence sensing by carbon nanoparticles
# Text-Mining URLs:
# Fluorescence sensing by carbon nanoparticles
# {}
# DOI:  10.1038/s41598-022-23055-6
# Title: Catalytic nanozyme Zn/Cl-doped carbon quantum dots as ratiometric fluorescent probe for sequential on-off-on detection of riboflavin, Cu2+ and thiamine
# Text-Mining URLs:
# application/pdf: https://www.nature.com/articles/s41598-022-23055-6.pdf
# text/html: https://www.nature.com/articles/s41598-022-23055-6
# Catalytic nanozyme Zn/Cl-doped carbon quantum dots as ratiometric fluorescent probe for sequential on-off-on detection of riboflavin, Cu2+ and thiamine
# {'application/pdf': 'https://www.nature.com/articles/s41598-022-23055-6.pdf', 'text/html': 'https://www.nature.com/articles/s41598-022-23055-6'}
# DOI:  10.1039/c7ra11383h
# Title: Cytidine-stabilized copper nanoclusters as a fluorescent probe for sensing of copper ions and hemin
# Text-Mining URLs:
# Cytidine-stabilized copper nanoclusters as a fluorescent probe for sensing of copper ions and hemin
# {}
# DOI:  10.1039/c7ra13404e
# Title: “Off–On” fluorescent sensing of organophosphate pesticides using a carbon dot–Au(<scp>iii</scp>) complex
# Text-Mining URLs:
# “Off–On” fluorescent sensing of organophosphate pesticides using a carbon dot–Au(<scp>iii</scp>) complex
# {}
# DOI:  10.1039/c8ra09298b
# Title: A novel highly fluorescent S, N, O co-doped carbon dots for biosensing and bioimaging of copper ions in live cells
# Text-Mining URLs:
# A novel highly fluorescent S, N, O co-doped carbon dots for biosensing and bioimaging of copper ions in live cells
# {}
# DOI:  10.1039/d0ra06383e
# Title: Environmentally exploitable biocide/fluorescent metal marker carbon quantum dots
# Text-Mining URLs:
# Environmentally exploitable biocide/fluorescent metal marker carbon quantum dots
# {}
# DOI:  10.1039/c8ra09729a
# Title: Bone-targeting carbon dots: effect of nitrogen-doping on binding affinity
# Text-Mining URLs:
# Bone-targeting carbon dots: effect of nitrogen-doping on binding affinity
# {}
# DOI:  10.1039/c9ra05689k
# Title: Catalysis with carbon nanoparticles
# Text-Mining URLs:
# Catalysis with carbon nanoparticles
# {}
# DOI:  10.1039/d2ra00039c
# Title: A portable visual coffee ring based on carbon dot sensitized lanthanide complex coordination to detect bisphenol A in water
# Text-Mining URLs:
# A portable visual coffee ring based on carbon dot sensitized lanthanide complex coordination to detect bisphenol A in water
# {}
# DOI:  10.3389/fchem.2022.875241
# Title: Recent Progress in Fluorescent Probes For Metal Ion Detection
# Text-Mining URLs:
# Recent Progress in Fluorescent Probes For Metal Ion Detection
# {}
# DOI:  10.1039/d0ra02276d
# Title: Efficient removal of Cu(<scp>ii</scp>) from aqueous systems using enhanced quantum yield nitrogen-doped carbon nanodots
# Text-Mining URLs:
# Efficient removal of Cu(<scp>ii</scp>) from aqueous systems using enhanced quantum yield nitrogen-doped carbon nanodots
# {}
# DOI:  10.32607/actanaturae.11180
# Title: Photoluminescent Nanomaterials for Medical Biotechnology
# Text-Mining URLs:
# application/pdf: https://actanaturae.ru/2075-8251/article/viewFile/11180/pdf_1
# Photoluminescent Nanomaterials for Medical Biotechnology
# {'application/pdf': 'https://actanaturae.ru/2075-8251/article/viewFile/11180/pdf_1'}
# DOI:  10.1016/j.bios.2021.113823
# Title: Horseradish peroxidase-triggered direct in situ fluorescent immunoassay platform for sensing cardiac troponin I and SARS-CoV-2 nucleocapsid protein in serum
# Text-Mining URLs:
# text/xml: https://api.elsevier.com/content/article/PII:S0956566321008605?httpAccept=text/xml
# text/plain: https://api.elsevier.com/content/article/PII:S0956566321008605?httpAccept=text/plain
# Horseradish peroxidase-triggered direct in situ fluorescent immunoassay platform for sensing cardiac troponin I and SARS-CoV-2 nucleocapsid protein in serum
# {'text/xml': 'https://api.elsevier.com/content/article/PII:S0956566321008605?httpAccept=text/xml', 'text/plain': 'https://api.elsevier.com/content/article/PII:S0956566321008605?httpAccept=text/plain'}
# DOI:  10.3390/nano12060898
# Title: Synthesis of Doped/Hybrid Carbon Dots and Their Biomedical Application
# Text-Mining URLs:
# Synthesis of Doped/Hybrid Carbon Dots and Their Biomedical Application
# {}
# DOI:  10.3390/ma14061504
# Title: Non-Invasive Topical Drug-Delivery System Using Hyaluronate Nanogels Crosslinked via Click Chemistry
# Text-Mining URLs:
# Non-Invasive Topical Drug-Delivery System Using Hyaluronate Nanogels Crosslinked via Click Chemistry
# {}
# DOI:  10.3390/nano11051265
# Title: A Comparative Study of Top-Down and Bottom-Up Carbon Nanodots and Their Interaction with Mercury Ions
# Text-Mining URLs:
# A Comparative Study of Top-Down and Bottom-Up Carbon Nanodots and Their Interaction with Mercury Ions
# {}
# DOI:  10.3390/nano11051232
# Title: Noval Dual-Emission Fluorescence Carbon Dots as a Ratiometric Probe for Cu2+ and ClO− Detection
# Text-Mining URLs:
# Noval Dual-Emission Fluorescence Carbon Dots as a Ratiometric Probe for Cu2+ and ClO− Detection
# {}
# DOI:  10.1016/j.isci.2020.101344
# Title: A DNA-Based FLIM Reporter for Simultaneous Quantification of Lysosomal pH and Ca2+ during Autophagy Regulation
# Text-Mining URLs:
# text/xml: https://api.elsevier.com/content/article/PII:S2589004220305319?httpAccept=text/xml
# text/plain: https://api.elsevier.com/content/article/PII:S2589004220305319?httpAccept=text/plain
# A DNA-Based FLIM Reporter for Simultaneous Quantification of Lysosomal pH and Ca2+ during Autophagy Regulation
# {'text/xml': 'https://api.elsevier.com/content/article/PII:S2589004220305319?httpAccept=text/xml', 'text/plain': 'https://api.elsevier.com/content/article/PII:S2589004220305319?httpAccept=text/plain'}
# DOI:  10.3389/fchem.2020.580033
# Title: A Perspective on Application of Carbon Quantum Dots in Luminescence Immunoassays
# Text-Mining URLs:
# A Perspective on Application of Carbon Quantum Dots in Luminescence Immunoassays
# {}
# DOI:  10.3390/molecules25235731
# Title: Supramolecular Sensing of a Chemical Warfare Agents Simulant by Functionalized Carbon Nanoparticles
# Text-Mining URLs:
# Supramolecular Sensing of a Chemical Warfare Agents Simulant by Functionalized Carbon Nanoparticles
# {}
# DOI:  10.1039/c9na00168a
# Title: Cupredoxin engineered upconversion nanoparticles for ratiometric luminescence sensing of Cu<sup>2+</sup>
# Text-Mining URLs:
# Cupredoxin engineered upconversion nanoparticles for ratiometric luminescence sensing of Cu<sup>2+</sup>
# {}
# DOI:  10.1371/journal.pone.0230646
# Title: Ultrasensitive fluorescent detection of pesticides in real sample by using green carbon dots
# Text-Mining URLs:
# Ultrasensitive fluorescent detection of pesticides in real sample by using green carbon dots
# {}
# DOI:  10.1002/advs.201903525
# Title: Near‐Infrared Chemiluminescent Carbon Nanodots and Their Application in Reactive Oxygen Species Bioimaging
# Text-Mining URLs:
# application/pdf: https://onlinelibrary.wiley.com/doi/pdf/10.1002/advs.201903525
# application/xml: https://onlinelibrary.wiley.com/doi/full-xml/10.1002/advs.201903525
# Near‐Infrared Chemiluminescent Carbon Nanodots and Their Application in Reactive Oxygen Species Bioimaging
# {'application/pdf': 'https://onlinelibrary.wiley.com/doi/pdf/10.1002/advs.201903525', 'application/xml': 'https://onlinelibrary.wiley.com/doi/full-xml/10.1002/advs.201903525'}
# DOI:  10.1021/acsomega.8b01159
# Title: Dual-Emissive Carbon Quantum Dot-Tb Nanocomposite as a Fluorescent Indicator for a Highly Selective Visual Detection of Hg(II) in Water
# Text-Mining URLs:
# Dual-Emissive Carbon Quantum Dot-Tb Nanocomposite as a Fluorescent Indicator for a Highly Selective Visual Detection of Hg(II) in Water
# {}
# DOI:  10.3390/nano9101500
# Title: Facile Synthesis of Nitrogen-Doped Carbon Dots from Lignocellulosic Waste
# Text-Mining URLs:
# Facile Synthesis of Nitrogen-Doped Carbon Dots from Lignocellulosic Waste
# {}
# DOI:  No full text available
# Error: Client error '404 Not Found' for url 'https://api.crossref.org/works/No'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/404
# Warning: No data found for DOI No full text available
# DOI:  10.1186/s11671-019-3088-6
# Title: Carbon Dots as an Effective Fluorescent Sensing Platform for Metal Ion Detection
# Text-Mining URLs:
# application/pdf: http://link.springer.com/content/pdf/10.1186/s11671-019-3088-6.pdf
# text/html: http://link.springer.com/article/10.1186/s11671-019-3088-6/fulltext.html
# Carbon Dots as an Effective Fluorescent Sensing Platform for Metal Ion Detection
# {'application/pdf': 'http://link.springer.com/content/pdf/10.1186/s11671-019-3088-6.pdf', 'text/html': 'http://link.springer.com/article/10.1186/s11671-019-3088-6/fulltext.html'}
# DOI:  10.1021/acsomega.7b01014
# Title: One-Step Synthesis of Acidophilic Highly-Photoluminescent Carbon Dots Modified by Ionic Liquid from Polyethylene Glycol
# Text-Mining URLs:
# One-Step Synthesis of Acidophilic Highly-Photoluminescent Carbon Dots Modified by Ionic Liquid from Polyethylene Glycol
# {}
# DOI:  10.1021/acsomega.8b00047
# Title: Brightly Fluorescent Zinc-Doped Red-Emitting Carbon Dots for the Sunlight-Induced Photoreduction of Cr(VI) to Cr(III)
# Text-Mining URLs:
# Brightly Fluorescent Zinc-Doped Red-Emitting Carbon Dots for the Sunlight-Induced Photoreduction of Cr(VI) to Cr(III)
# {}
# DOI:  10.1021/jacs.9b02369
# Title: Molecular Surface Functionalization of Carbon Materials via Radical-Induced Grafting of Terminal Alkenes
# Text-Mining URLs:
# Molecular Surface Functionalization of Carbon Materials via Radical-Induced Grafting of Terminal Alkenes
# {}
# DOI:  10.1021/acs.est.9b01453
# Title: Next-Generation Multifunctional Carbon–Metal Nanohybrids for Energy and Environmental Applications
# Text-Mining URLs:
# Next-Generation Multifunctional Carbon–Metal Nanohybrids for Energy and Environmental Applications
# {}
# DOI:  No full text available
# Error: Client error '404 Not Found' for url 'https://api.crossref.org/works/No'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/404
# Warning: No data found for DOI No full text available
# DOI:  10.1007/s40820-015-0077-x
# Title: Biomedical Perspective of Electrochemical Nanobiosensor
# Text-Mining URLs:
# application/pdf: http://link.springer.com/content/pdf/10.1007/s40820-015-0077-x.pdf
# text/html: http://link.springer.com/article/10.1007/s40820-015-0077-x/fulltext.html
# Biomedical Perspective of Electrochemical Nanobiosensor
# {'application/pdf': 'http://link.springer.com/content/pdf/10.1007/s40820-015-0077-x.pdf', 'text/html': 'http://link.springer.com/article/10.1007/s40820-015-0077-x/fulltext.html'}
# DOI:  10.3390/nano8121071
# Title: Phenanthroline-Derivative Functionalized Carbon Dots for Highly Selective and Sensitive Detection of Cu2+ and S2− and Imaging inside Live Cells
# Text-Mining URLs:
# Phenanthroline-Derivative Functionalized Carbon Dots for Highly Selective and Sensitive Detection of Cu2+ and S2− and Imaging inside Live Cells
# {}
# DOI:  No full text available
# Error: Client error '404 Not Found' for url 'https://api.crossref.org/works/No'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/404
# Warning: No data found for DOI No full text available
# DOI:  10.1038/s41598-017-18338-2
# Title: Tunable direct band gap photoluminescent organic semiconducting nanoparticles from lignite
# Text-Mining URLs:
# application/pdf: https://www.nature.com/articles/s41598-017-18338-2.pdf
# text/html: https://www.nature.com/articles/s41598-017-18338-2
# Tunable direct band gap photoluminescent organic semiconducting nanoparticles from lignite
# {'application/pdf': 'https://www.nature.com/articles/s41598-017-18338-2.pdf', 'text/html': 'https://www.nature.com/articles/s41598-017-18338-2'}
# DOI:  10.1186/s11671-018-2440-6
# Title: Molecularly Imprinted Core-Shell CdSe@SiO2/CDs as a Ratiometric Fluorescent Probe for 4-Nitrophenol Sensing
# Text-Mining URLs:
# text/html: http://link.springer.com/article/10.1186/s11671-018-2440-6/fulltext.html
# application/pdf: http://link.springer.com/content/pdf/10.1186/s11671-018-2440-6.pdf
# Molecularly Imprinted Core-Shell CdSe@SiO2/CDs as a Ratiometric Fluorescent Probe for 4-Nitrophenol Sensing
# {'text/html': 'http://link.springer.com/article/10.1186/s11671-018-2440-6/fulltext.html', 'application/pdf': 'http://link.springer.com/content/pdf/10.1186/s11671-018-2440-6.pdf'}
# DOI:  No full text available
# Error: Client error '404 Not Found' for url 'https://api.crossref.org/works/No'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/404
# Warning: No data found for DOI No full text available
# DOI:  10.1186/s11671-017-2137-2
# Title: High-Efficient Excitation-Independent Blue Luminescent Carbon Dots
# Text-Mining URLs:
# application/pdf: http://link.springer.com/content/pdf/10.1186/s11671-017-2137-2.pdf
# text/html: http://link.springer.com/article/10.1186/s11671-017-2137-2/fulltext.html
# High-Efficient Excitation-Independent Blue Luminescent Carbon Dots
# {'application/pdf': 'http://link.springer.com/content/pdf/10.1186/s11671-017-2137-2.pdf', 'text/html': 'http://link.springer.com/article/10.1186/s11671-017-2137-2/fulltext.html'}
# DOI:  10.1039/c5sc00819k
# Title: Sub-5 nm porous nanocrystals: interfacial site-directed growth on graphene for efficient biocatalysis
# Text-Mining URLs:
# Sub-5 nm porous nanocrystals: interfacial site-directed growth on graphene for efficient biocatalysis
# {}
# DOI:  10.1038/s41598-017-06356-z
# Title: Nitrogen-doped Carbon Dots Mediated Fluorescent on-off Assay for Rapid and Highly Sensitive Pyrophosphate and Alkaline Phosphatase Detection
# Text-Mining URLs:
# application/pdf: https://www.nature.com/articles/s41598-017-06356-z.pdf
# text/html: https://www.nature.com/articles/s41598-017-06356-z
# Nitrogen-doped Carbon Dots Mediated Fluorescent on-off Assay for Rapid and Highly Sensitive Pyrophosphate and Alkaline Phosphatase Detection
# {'application/pdf': 'https://www.nature.com/articles/s41598-017-06356-z.pdf', 'text/html': 'https://www.nature.com/articles/s41598-017-06356-z'}
# DOI:  10.1038/srep36794
# Title: A RGB-Type Quantum Dot-based Sensor Array for Sensitive Visual Detection of Trace Formaldehyde in Air
# Text-Mining URLs:
# application/pdf: https://www.nature.com/articles/srep36794.pdf
# text/html: https://www.nature.com/articles/srep36794
# A RGB-Type Quantum Dot-based Sensor Array for Sensitive Visual Detection of Trace Formaldehyde in Air
# {'application/pdf': 'https://www.nature.com/articles/srep36794.pdf', 'text/html': 'https://www.nature.com/articles/srep36794'}
# DOI:  10.1021/acsami.6b13954
# Title: Drug-Derived Bright and Color-Tunable N-Doped Carbon Dots for Cell Imaging and Sensitive Detection of Fe<sup>3+</sup> in Living Cells
# Text-Mining URLs:
# Drug-Derived Bright and Color-Tunable N-Doped Carbon Dots for Cell Imaging and Sensitive Detection of Fe<sup>3+</sup> in Living Cells
# {}
# DOI:  10.1002/adfm.201500624
# Title: Integrative Self‐Assembly of Graphene Quantum Dots and Biopolymers into a Versatile Biosensing Toolkit
# Text-Mining URLs:
# unspecified: https://api.wiley.com/onlinelibrary/tdm/v1/articles/10.1002%2Fadfm.201500624
# Integrative Self‐Assembly of Graphene Quantum Dots and Biopolymers into a Versatile Biosensing Toolkit
# {'unspecified': 'https://api.wiley.com/onlinelibrary/tdm/v1/articles/10.1002%2Fadfm.201500624'}
# DOI:  10.1016/j.addr.2016.05.023
# Title: Imaging the pharmacology of nanomaterials by intravital microscopy: Toward understanding their biological behavior
# Text-Mining URLs:
# text/xml: http://api.elsevier.com/content/article/PII:S0169409X16301831?httpAccept=text/xml
# text/plain: http://api.elsevier.com/content/article/PII:S0169409X16301831?httpAccept=text/plain
# Imaging the pharmacology of nanomaterials by intravital microscopy: Toward understanding their biological behavior
# {'text/xml': 'http://api.elsevier.com/content/article/PII:S0169409X16301831?httpAccept=text/xml', 'text/plain': 'http://api.elsevier.com/content/article/PII:S0169409X16301831?httpAccept=text/plain'}
# DOI:  10.1038/srep35565
# Title: Sensitive detection of copper ions via ion-responsive fluorescence quenching of engineered porous silicon nanoparticles
# Text-Mining URLs:
# application/pdf: https://www.nature.com/articles/srep35565.pdf
# text/html: https://www.nature.com/articles/srep35565
# Sensitive detection of copper ions via ion-responsive fluorescence quenching of engineered porous silicon nanoparticles
# {'application/pdf': 'https://www.nature.com/articles/srep35565.pdf', 'text/html': 'https://www.nature.com/articles/srep35565'}
# DOI:  10.1016/j.nantod.2016.05.010
# Title: Fluorescent nanoprobes for sensing and imaging of metal ions: Recent advances and future perspectives
# Text-Mining URLs:
# text/xml: https://api.elsevier.com/content/article/PII:S174801321630024X?httpAccept=text/xml
# text/plain: https://api.elsevier.com/content/article/PII:S174801321630024X?httpAccept=text/plain
# Fluorescent nanoprobes for sensing and imaging of metal ions: Recent advances and future perspectives
# {'text/xml': 'https://api.elsevier.com/content/article/PII:S174801321630024X?httpAccept=text/xml', 'text/plain': 'https://api.elsevier.com/content/article/PII:S174801321630024X?httpAccept=text/plain'}
# DOI:  10.1038/srep02933
# Title: A two-photon ratiometric fluorescence probe for Cupric Ions in Live Cells and Tissues
# Text-Mining URLs:
# text/html: https://www.nature.com/articles/srep02933
# application/pdf: https://www.nature.com/articles/srep02933.pdf
# A two-photon ratiometric fluorescence probe for Cupric Ions in Live Cells and Tissues
# {'text/html': 'https://www.nature.com/articles/srep02933', 'application/pdf': 'https://www.nature.com/articles/srep02933.pdf'}
# DOI:  10.1038/srep03564
# Title: Non-Enzymatic-Browning-Reaction: A Versatile Route for Production of Nitrogen-Doped Carbon Dots with Tunable Multicolor Luminescent Display
# Text-Mining URLs:
# application/pdf: https://www.nature.com/articles/srep03564.pdf
# text/html: https://www.nature.com/articles/srep03564
# Non-Enzymatic-Browning-Reaction: A Versatile Route for Production of Nitrogen-Doped Carbon Dots with Tunable Multicolor Luminescent Display
# {'application/pdf': 'https://www.nature.com/articles/srep03564.pdf', 'text/html': 'https://www.nature.com/articles/srep03564'}
# DOI:  10.1186/1556-276X-9-583
# Title: The effect of pristine carbon-based nanomaterial on the growth of green gram sprouts and pH of water
# Text-Mining URLs:
# The effect of pristine carbon-based nanomaterial on the growth of green gram sprouts and pH of water
# {}
# DOI:  10.1038/srep01473
# Title: Carbon Nanoparticle-based Fluorescent Bioimaging Probes
# Text-Mining URLs:
# text/html: https://www.nature.com/articles/srep01473
# application/pdf: https://www.nature.com/articles/srep01473.pdf
# Carbon Nanoparticle-based Fluorescent Bioimaging Probes
# {'text/html': 'https://www.nature.com/articles/srep01473', 'application/pdf': 'https://www.nature.com/articles/srep01473.pdf'}

# %%
import requests
import csv

def get_opencitations(doi):
    doi_encoded = requests.utils.quote(doi)
    url = f"https://opencitations.net/index/coci/api/v1/citations/{doi_encoded}"
    response = requests.get(url)
    cited_dois = []
    if response.status_code == 200:
        for item in response.json():
            citing_doi = item.get('citing')
            if citing_doi:
                cited_dois.append(citing_doi)
    return cited_dois

def get_semantic_scholar(doi):
    url = f"https://api.semanticscholar.org/graph/v1/paper/DOI:{doi}?fields=citations.paperId,citations.externalIds"
    response = requests.get(url)
    cited_dois = []
    if response.status_code == 200:
        data = response.json()
        citations = data.get('citations', [])
        for citation in citations:
            ext_ids = citation.get('externalIds', {})
            citing_doi = ext_ids.get('DOI')
            if citing_doi:
                cited_dois.append(citing_doi)
    return cited_dois

def get_crossref(doi):
    url = f"https://api.crossref.org/works/{doi}"
    response = requests.get(url)
    citation_count = None
    if response.status_code == 200:
        data = response.json()
        citation_count = data['message'].get('is-referenced-by-count')
    return citation_count

def cross_check_citations(doi):
    print(f"Cross-checking DOI: {doi}\n")

    # OpenCitations
    oc_dois = get_opencitations(doi)
    print(f"OpenCitations: {len(oc_dois)} citing DOIs found.")

    # Semantic Scholar
    ss_dois = get_semantic_scholar(doi)
    print(f"Semantic Scholar: {len(ss_dois)} citing DOIs found.")

    # Crossref (gives citation count but no DOIs)
    cr_count = get_crossref(doi)
    print(f"Crossref metadata says: {cr_count} citations (count only, no list).")

    # Optional: compare overlap
    overlap = set(oc_dois) & set(ss_dois)
    print(f"\nOverlap between OpenCitations & Semantic Scholar: {len(overlap)} DOIs")

    # Save to TSV
    with open('citations.tsv', 'w', newline='', encoding='utf-8') as tsvfile:
        writer = csv.writer(tsvfile, delimiter='\t')
        writer.writerow(['OpenCitations_DOI', 'SemanticScholar_DOI'])
        max_len = max(len(oc_dois), len(ss_dois))
        for i in range(max_len):
            oc_doi = oc_dois[i] if i < len(oc_dois) else ''
            ss_doi = ss_dois[i] if i < len(ss_dois) else ''
            writer.writerow([oc_doi, ss_doi])

    print("\nDOIs saved to citations.tsv")

    return {
        "OpenCitations": oc_dois,
        "SemanticScholar": ss_dois,
        "CrossrefCount": cr_count
    }

doi = "10.1002/anie.201109089"
results = cross_check_citations(doi)
# Out:
# Cross-checking DOI: 10.1002/anie.201109089
#
# OpenCitations: 484 citing DOIs found.
# Semantic Scholar: 544 citing DOIs found.
# Crossref metadata says: 499 citations (count only, no list).
#
# Overlap between OpenCitations & Semantic Scholar: 332 DOIs
#
# DOIs saved to citations.tsv

# %%
import pandas as pd

def cross_check_citations(doi):
    print(f"Cross-checking DOI: {doi}\n")

    # Load your citing DOIs from TSV
    my_df = pd.read_csv('citing_dois.tsv', sep='\t', dtype=str)
    input_dois = set(my_df['DOI'].dropna())

    # OpenCitations
    oc_dois = get_opencitations(doi)
    print(f"OpenCitations: {len(oc_dois)} citing DOIs found.")

    # Semantic Scholar
    ss_dois = get_semantic_scholar(doi)
    print(f"Semantic Scholar: {len(ss_dois)} citing DOIs found.")

    # Crossref count
    cr_count = get_crossref(doi)
    print(f"Crossref metadata says: {cr_count} citations (count only, no list).")

    # Sets
    set_oc = set(oc_dois)
    set_ss = set(ss_dois)

    # Overlap between API sources
    overlap_oc_ss = set_oc & set_ss

    # Overlap with your dataframe DOIs
    overlap_input_oc = input_dois & set_oc
    overlap_input_ss = input_dois & set_ss
    overlap_input_both = input_dois & overlap_oc_ss

    print(f"\nOverlap between OpenCitations & Semantic Scholar: {len(overlap_oc_ss)} DOIs")
    print(f"Overlap between your input DOIs & OpenCitations: {len(overlap_input_oc)} DOIs")
    print(f"Overlap between your input DOIs & Semantic Scholar: {len(overlap_input_ss)} DOIs")
    print(f"DOIs present in ALL THREE (your input, OC, SS): {len(overlap_input_both)} DOIs")

    # Optional: print the DOIs found in all three sources
    """print("\nDOIs in aPMC and OC:")
    for doi in overlap_input_oc:
        print(doi)
        
    print("\nDOIs in PMC and SS:")
    for doi in overlap_input_ss:
        print(doi)"""

    # Save to TSV
    with open('citations.tsv', 'w', newline='', encoding='utf-8') as tsvfile:
        writer = csv.writer(tsvfile, delimiter='\t')
        writer.writerow(['OpenCitations_DOI', 'SemanticScholar_DOI'])
        max_len = max(len(oc_dois), len(ss_dois))
        for i in range(max_len):
            oc_doi = oc_dois[i] if i < len(oc_dois) else ''
            ss_doi = ss_dois[i] if i < len(ss_dois) else ''
            writer.writerow([oc_doi, ss_doi])

    print("\nDOIs saved to citations.tsv")

    return {
        "OpenCitations": oc_dois,
        "SemanticScholar": ss_dois,
        "CrossrefCount": cr_count,
        "Overlap_Input_OC": list(overlap_input_oc),
        "Overlap_Input_SS": list(overlap_input_ss),
        "Overlap_Input_Both": list(overlap_input_both)
    }

# %%
dois = cross_check_citations("10.1002/anie.201109089")
print(dois)
# Out:
# Cross-checking DOI: 10.1002/anie.201109089
#
# OpenCitations: 484 citing DOIs found.
# Semantic Scholar: 544 citing DOIs found.
# Crossref metadata says: 499 citations (count only, no list).
#
# Overlap between OpenCitations & Semantic Scholar: 332 DOIs
# Overlap between your input DOIs & OpenCitations: 46 DOIs
# Overlap between your input DOIs & Semantic Scholar: 54 DOIs
# DOIs present in ALL THREE (your input, OC, SS): 44 DOIs
#
# DOIs saved to citations.tsv
# {'OpenCitations': ['10.1039/d0nj01814g', '10.1021/acs.chemrev.5b00008', '10.1039/c9qm00415g', '10.1007/s00604-018-3043-8', '10.1039/c9na00794f', '10.1039/c9na00168a', '10.1038/s41598-017-06356-z', '10.1038/srep03564', '10.1039/c5an00957j', '10.1021/acsapm.2c02098', '10.1039/c2jm32973e', '10.1016/j.snb.2020.127916', '10.1039/c9ra05689k', '10.1021/jp307308z', '10.1007/978-3-030-38101-1_5', '10.1016/j.matpr.2020.11.417', '10.1016/j.jhazmat.2019.02.008', '10.1016/b978-0-323-47906-6.00001-1', '10.1039/c2cc35966a', '10.1039/c7nr03754f', '10.1016/j.snb.2015.05.006', '10.1016/j.aca.2013.10.046', '10.1021/acs.analchem.9b05490', '10.1039/c5nj00170f', '10.1039/c4nj00966e', '10.1021/nl500276x', '10.1016/j.jphotochem.2019.111938', '10.1016/j.jphotochem.2019.111918', '10.1002/viw.20200089', '10.1002/sstr.202200033', '10.1016/b978-0-12-814497-8.00005-9', '10.1016/j.jhazmat.2017.08.020', '10.1002/ppsc.201900489', '10.1002/ppsc.201700471', '10.1002/ppsc.201500062', '10.1002/cphc.201601249', '10.1021/acsami.0c22077', '10.1016/j.snb.2022.132888', '10.1088/0957-4484/24/13/135602', '10.1039/c6nr03129c', '10.1016/j.snb.2014.09.016', '10.1016/j.saa.2021.120681', '10.1021/acs.jafc.9b03222', '10.1039/c7ra03493h', '10.1002/advs.201903525', '10.1002/ange.201508635', '10.1039/d1tc00660f', '10.1039/d0tc04007j', '10.1016/j.cej.2020.124182', '10.1002/ppsc.201400055', '10.1021/acsami.5b12084', '10.1021/acsami.5b11317', '10.1021/acsami.5b11551', '10.1039/c9cc05406e', '10.1016/j.mattod.2015.11.008', '10.1038/s41598-022-23055-6', '10.1039/d0dt00729c', '10.1039/c6nr01912a', '10.1039/c6nr00430j', '10.1039/c5nr07826a', '10.1016/j.apsusc.2017.08.133', '10.1039/c5ra05519a', '10.1039/c5ra04544d', '10.1016/j.talanta.2020.121691', '10.1016/j.talanta.2020.121621', '10.1016/j.talanta.2020.121355', '10.1371/journal.pone.0230646', '10.1002/adom.201900659', '10.1002/chem.201502731', '10.1016/j.molstruc.2022.132485', '10.1016/b978-0-323-47906-6.00004-7', '10.1021/acsami.5b08499', '10.1039/c9cc01825e', '10.3390/app13063991', '10.1039/c5nr04466a', '10.1039/c5nr04361a', '10.1016/j.saa.2020.118592', '10.1016/j.saa.2019.117485', '10.1021/acs.analchem.8b03992', '10.1021/acs.analchem.8b05360', '10.1002/anie.201814282', '10.1016/j.talanta.2019.120534', '10.1039/c8sm01155a', '10.1002/chem.201502463', '10.1021/acs.inorgchem.5b00610', '10.1016/j.colsurfa.2021.127299', '10.1021/acsami.5b04172', '10.1016/j.ccr.2020.213727', '10.1016/j.matchemphys.2022.126772', '10.1002/advs.202207621', '10.1016/j.diamond.2023.110275', '10.1016/j.jcis.2020.02.011', '10.1016/j.saa.2019.03.108', '10.1016/j.saa.2018.12.036', '10.1016/j.saa.2018.10.002', '10.1039/d2ra00039c', '10.1021/acs.analchem.8b01574', '10.1002/anie.201811703', '10.1002/adom.201400307', '10.1039/c9tc00233b', '10.1016/j.ceramint.2017.02.127', '10.1002/chem.201406143', '10.1039/d0tb02979c', '10.1021/acsami.5b00758', '10.1016/j.ccr.2019.213113', '10.1016/j.jlumin.2017.12.062', '10.1039/d0cp00952k', '10.1080/03067319.2020.1759563', '10.1016/j.jcis.2019.07.022', '10.1016/j.apsusc.2016.07.048', '10.1016/j.saa.2017.10.026', '10.1039/c6ra26048a', '10.1039/c6ra25148j', '10.1021/acs.analchem.7b05149', '10.1021/acs.analchem.7b04934', '10.1021/acs.analchem.7b05365', '10.1021/acs.analchem.7b03053', '10.1016/j.talanta.2018.03.054', '10.1016/j.colsurfb.2014.06.002', '10.1038/srep36794', '10.1039/d1tb00224d', '10.1016/j.ccr.2015.11.012', '10.1021/acs.analchem.2c02466', '10.1016/j.ijhydene.2022.09.184', '10.1002/9780470027318.a9531', '10.1016/j.physe.2015.04.006', '10.1039/c4nr02792b', '10.1039/c4nr02657h', '10.1039/c4nr01030b', '10.1039/c4nr00029c', '10.1016/j.talanta.2017.06.027', '10.1016/j.talanta.2017.05.071', '10.1002/ange.202106193', '10.1002/ange.201306688', '10.1016/j.molliq.2020.113086', '10.1016/j.molliq.2020.112593', '10.1039/c7tc03266h', '10.2174/2213337206666190702165008', '10.1016/j.chemosphere.2022.134815', '10.1039/c9tb02758k', '10.1021/acsami.9b20785', '10.1021/am504824n', '10.1007/s11051-022-05492-6', '10.1039/d1ay01716k', '10.1039/c8c ...

# %%
my_df = pd.read_csv('citing_dois.tsv', sep='\t', dtype=str)
input_dois = set(my_df['DOI'].dropna())

# %%
import requests

def check_open_access(doi):
    url = f"https://api.unpaywall.org/v2/{doi}"
    params = {
        "email": "recheinje@gmail.com"
    }
    response = requests.get(url, params=params)
    if response.status_code == 200:
        data = response.json()
        if data.get('is_oa'): 
            link[doi] = data.get('best_oa_location', {}).get('url')
            #print(f"DOI: {doi} is Open Access")
            #print(f"OA URL: {data.get('best_oa_location', {}).get('url')}")
        else:
            print(f"DOI: {doi} is not Open Access")
    else:
        print(f"Error: {response.status_code} for DOI: {doi}")

# Example usage
#doi = "10.3390/nano11051232"  # Replace with any DOI you want to check
link = {}
i = 0

for doi in input_dois:
    check_open_access(doi)
# Out:
# Error: 404 for DOI: No full text available

# %%
print(len(input_dois))
print(len(link))
# Out:
# 60
# 59

# %%
import re
import time
import json
import random
import requests
import pandas as pd
from tqdm import tqdm
from itertools import islice
from multiprocessing import Pool
import xml.etree.ElementTree as ET
from concurrent.futures import ThreadPoolExecutor, as_completed

# %%
url = "https://www.ncbi.nlm.nih.gov/pmc/utils/idconv/v1.0/"
key = ".."
#_________the email is needed for the crossref abstract extraction__________
#mail = email adress
cross = "https://api.crossref.org/works/"

# %% [markdown]
# # **Extract all citations in xml file:**
# 1. Remove all citations that have no DOI
# 2. Save a df with unique DOI

# %%
import pandas as pd
import xml.etree.ElementTree as ET

def split_sentences(text):
    """Splits text into sentences without using nltk.punkt."""
    return re.split(r'(?<=[.!?])\s+', text)  # Splits at sentence-ending punctuation

def extract_pmc_citations(xml_file):
    """Extract citations from a given PMC XML file using ElementTree for faster parsing."""
    tree = ET.parse(xml_file)
    root = tree.getroot()
    
    # Get the citing article's DOI
    citing_doi = None
    for article_id in root.findall(".//article-id"):
        if article_id.get("pub-id-type") == "doi":
            citing_doi = article_id.text
            break

    # Extract reference list
    ref_dict = {}
    for ref in root.findall(".//ref"):
        ref_id = ref.get("id")
        title_elem = ref.find(".//article-title")
        doi_elem = ref.find(".//pub-id[@pub-id-type='doi']")
        ref_dict[ref_id] = {
            "title": title_elem.text.strip() if title_elem is not None and title_elem.text else "No title",
            "doi": doi_elem.text.strip() if doi_elem is not None and doi_elem.text else "No DOI",
        }
    
    # Extract citations from text
    data = []
    for paragraph in root.findall(".//p"):
        text = " ".join(paragraph.itertext()).strip()
        sentences = split_sentences(text)
        citation_matches = paragraph.findall(".//xref")

        for citation in citation_matches:
            citation_id = citation.get("rid")
            if citation_id in ref_dict:
                sentence_index = next((i for i, s in enumerate(sentences) if citation.text and citation.text in s), None)
                previous_sentence = sentences[sentence_index - 1] if sentence_index and sentence_index > 0 else None
                if previous_sentence:
                    previous_sentence = re.sub(r'\[.*?\]|\(.*?\)|\{.*?\}|\n.*?\n', '', previous_sentence).strip()
                    data.append([citing_doi, citation_id, previous_sentence, ref_dict[citation_id]["title"], ref_dict[citation_id]["doi"]])
    
    df = pd.DataFrame(data, columns=["Citing DOI", "Citation ID", "Citation Context", "Cited Title", "DOI"])
    df = df.drop(df[df['DOI'] == 'No DOI'].index) # Remove useless rows to save space
    return (df, df.drop_duplicates(subset=['DOI']))


start_time = time.time()
pmc_citations_df, unique_dois = extract_pmc_citations("../pmc_xml/10663565.xml")
print(f"Completed in {round(time.time() - start_time, 2)} seconds.")
#display(pmc_citations_df)
display(unique_dois)
# Out:
# Completed in 0.01 seconds.
#                     Citing DOI Citation ID  \
# 0   10.1038/s41598-023-47358-4         CR5
# 1   10.1038/s41598-023-47358-4         CR7
# 2   10.1038/s41598-023-47358-4         CR8
# 6   10.1038/s41598-023-47358-4        CR13
# 7   10.1038/s41598-023-47358-4        CR15
# 8   10.1038/s41598-023-47358-4        CR16
# 9   10.1038/s41598-023-47358-4        CR18
# 10  10.1038/s41598-023-47358-4        CR19
# 12  10.1038/s41598-023-47358-4        CR21
# 14  10.1038/s41598-023-47358-4        CR23
# 15  10.1038/s41598-023-47358-4        CR24
# 16  10.1038/s41598-023-47358-4        CR29
# 17  10.1038/s41598-023-47358-4        CR30
# 18  10.1038/s41598-023-47358-4        CR33
# 20  10.1038/s41598-023-47358-4        CR37
# 21  10.1038/s41598-023-47358-4        CR38
# 22  10.1038/s41598-023-47358-4        CR39
# 24  10.1038/s41598-023-47358-4        CR41
# 25  10.1038/s41598-023-47358-4        CR42
# 26  10.1038/s41598-023-47358-4        CR43
# 27  10.1038/s41598-023-47358-4        CR45
# 28  10.1038/s41598-023-47358-4        CR46
# 29  10.1038/s41598-023-47358-4        CR47
# 30  10.1038/s41598-023-47358-4        CR48
# 31  10.1038/s41598-023-47358-4        CR49
# 32  10.1038/s41598-023-47358-4        CR50
# 33  10.1038/s41598-023-47358-4        CR51
# 34  10.1038/s41598-023-47358-4        CR52
# 35  10.1038/s41598-023-47358-4        CR63
# 36  10.1038/s41598-023-47358-4        CR64
# 38  10.1038/s41598-023-47358-4        CR66
# 39  10.1038/s41598-023-47358-4        CR68
# 41  10.1038/s41598-023-47358-4        CR70
# 42  10.1038/s41598-023-47358-4        CR71
# 43  10.1038/s41598-023-47358-4        CR72
# 45  10.1038/s41598-023-47358-4        CR73
# 47  10.1038/s41598-023-47358-4        CR74
# 48  10.1038/s41598-023-47358-4        CR75
# 49  10.1038/s41598-023-47358-4        CR76
# 50  10.1038/s41598-023-47358-4        CR77
#
#                                      Citation Context  \
# 0   Due to increasing environmental problems, find...
# 1   Due to increasing environmental problems, find...
# 2   For this purpose, economic and biocompatible a...
# 6   Nanotechnology is one of the newest and most e...
# 7   Nanotechnology is one of the newest and most e...
# 8   The utilization of biologic materials such as ...
# 9   The utilization of biologic materials such as ...
# 10  These eco-friendly condition are more efficien...
# 12  Green methods may synthesize NPs with better s...
# 14  The reduction of metal ions using plant extrac...
# 15  It is suggested that water-soluble plant metab...
# 16  It is suggested that water-soluble plant metab...
# 17  The synthesized metallic NPs have unique optic...
# 18  The synthesized metallic NPs have unique optic...
# 20  Synergistic biological effects may be observed...
# 21  Purple cabbage  ( Brassica oleracea var.capita...
# 22  rubra ) is one of the plants that can be used ...
# 24  It is a herbaceous, two-year and dicotyledonou...
# 25  It is believed that glucosinolates, polyphenol...
# 26  It is considered as the best vegetable among  ...
# 27  It is considered as the best vegetable among  ...
# 28  Phenolic compounds are the main antioxidants i...
# 29  Among polyphenolic compounds, anthocyanins in ...
# 30  In addition to preventive measures, new antimi...
# 31  In addition to preventive measures, new antimi...
# 32  Ag and Cu sources such as metal NPs and comple...
# 33  Ag and Cu sources such as metal NPs and comple...
# 34  To conduct the experiment, 70 g of chopped  pu...
# 35  Phenolic compounds, especially anthocyanins, i...
# 36        The FT-IR spectrum of the Schiff base (Fig.
# 38  2 a) shows stretching vibrations of the O–H gr...
# 39  2 a) shows stretching vibrations of the O–H gr...
# 41  The peak in the region of 245 nm corresponds t...
# 42  The surface plasmon resonance  bands in the ra...
# 43  The peak related to Cu NPs is also observed ar...
# 45  2θ values of 10–80° were obtained for Cu and A...
# 47                                   aureus  strains.
# 48  Polymyxin B peptide is a naturally occurring a...
# 49  Polymyxin B peptide is a naturally occurring a...
# 50             against antibiotic-resistant bacteria.
#
#                                           Cited Title  \
# 0              Metal nanoparticles as green catalysts
# 1   Fe(III)-salen complex supported on dendrimer f...
# 2   Nickel nanoparticles adorned on magnetized cel...
# 6   A comprehensive review on green synthesis of n...
# 7         Biosynthesis of organic nanocomposite using
# 8                 Design and synthesis of magnetic Fe
# 9   New Acetamidine Cu(II) Schiff base complex sup...
# 10  Green synthesis of nanoparticles using plant e...
# 12  Bioinspired and green synthesis of nanoparticl...
# 14  Green synthesis of gold and silver nanoparticl...
# 15  Metal nanoparticles synthesis through natural ...
# 16  Cu/cellulose-modified magnetite nanocomposites...
# 17  A review on biosynthesis of metal nanoparticle...
# 18  Green synthesis of Cu nanoparticles using Curc...
# 20  Current trends and challenges in the synthesis...
# 21  Antibacterial activity of nanocomposites of si...
# 22                     Encapsulation of red cabbage (
# 24  Comparative study of young shoots and the matu...
# 25  Enhancement of phenolic and flavonoids compoun...
# 26  Red cabbage anthocyanins: Profile, isolation, ...
# 27  Growth performance and nutrient composition of...
# 28  Green synthesis of silver nanoparticles from a...
# 29  Global burden of bacterial antimicrobial resis...
# 30  Silver nanoparticles and their antibacterial a...
# 31                         Antibacterial effect of Cu
# 32  Mechanistic basis of antimicrobial actions of ...
# 33             Study on behaviour and mechanism of Cu
# 34  Comparative study on the extraction and quanti...
# 35  Silver nanoparticle biosynthesis by using phen...
# 36  Synthesis of cellulose nanofibers-based ImSalo...
# 38  Synthesis, characterization and cytotoxicity e...
# 39  Simple synthesis of the novel Cu-MOF catalysts...
# 41  Biogenic synthesis of copper and silver nanopa...
# 42  Bactericidal and in-vitro cytotoxic efficacy o...
# 43  Determination of total phenolic content in oli...
# 45  Biosynthesis, characterization and antimicrobi...
# 47                        Antibacterial therapy by Ag
# 48      Metal nanoparticles in infection and immunity
# 49  Synergistic Interaction between Silver Nanopar...
# 50  Development of multi-concentration Cu: Ag bime...
#
#                                   DOI
# 0                  10.3390/ma12213602
# 1          10.1016/j.jpcs.2020.109642
# 2          10.1007/s10570-022-04823-z
# 6       10.1016/j.jclepro.2020.122880
# 7                10.1155/2021/4105853
# 8                  10.1039/D0RA06251K
# 9          10.1038/s41598-022-07674-7
# 10         10.1007/s10311-020-01074-x
# 12         10.1016/j.jscs.2021.101304
# 14               10.3390/nano10091763
# 15          10.1049/iet-nbt.2018.5386
# 16          10.1016/j.scp.2022.100672
# 17  10.1016/j.chemosphere.2020.128580
# 18       10.1016/j.matlet.2019.126813
# 20      10.1016/j.carbpol.2021.117904
# 21       10.1016/j.actbio.2009.02.003
# 22       10.1590/S1516-89132015060226
# 24                 10.1039/D0RA07861A
# 25      10.1080/14786419.2018.1508145
# 26      10.1016/j.foodres.2012.12.015
# 27               10.3390/foods9020151
# 28    10.1088/1742-6596/2274/1/012001
# 29      10.1016/S0140-6736(21)02724-0
# 30               10.3390/ijms22137202
# 31       10.1016/j.vetmic.2005.04.021
# 32           10.3389/fmicb.2016.01831
# 33     10.1179/1753555714Y.0000000236
# 34             10.12944/CRNFSJ.7.3.08
# 35         10.1016/j.jfda.2017.07.005
# 36       10.1016/j.microc.2022.108368
# 38                 10.1039/D1RA01256H
# 39                   10.1002/aoc.5965
# 41               10.1155/2018/7879403
# 42               10.3390/nano10102082
# 43          10.1007/s12161-012-9379-5
# 45          10.1007/s13204-013-0233-x
# 47               10.3390/ijms23010026
# 48      10.1080/08820139.2020.1776724
# 49               10.1128/AAC.01106-08
# 50         10.1186/s11671-021-03547-6

# %%
bs = 150 # batch size
par = 10 # workers
batches = [unique_dois['DOI'][i:i + bs] for i in range(0, len(unique_dois['DOI']), bs)]
print(len(batches))
# Out:
# 1

# %% [markdown]
# # **Extract PMID:**
# 1. Save DOIs with PMID in a dico
# 2. Save DOIs with no PMID in a List

# %%
def fetch_ids_batch(doi_batch):
    """ 
    This function fetches PMIDS using batch resquest to minimize the request number. Recalls itself
    when the rate limit is exceeded, retries after 10 seconds on the same batch that failed. 
    """
    no_id = []
    pid = {}
    params = {'format': 'json','ids': ','.join(doi_batch), 'api_key': key}
    
    try:
        response = requests.get(url, params=params, timeout=10)
        if response.status_code == 200:
            data = response.json()
            for rec in data.get('records', []):
                if 'pmid' in rec:
                    pid.update({rec['doi']: rec['pmid']})
                else : 
                    no_id.append(rec['doi'])
            return (pid, no_id)
        elif response.status_code == 429:
            print("Rate limit exceeded! Retrying after 10 seconds...")
            time.sleep(10)
            return fetch_ids_batch(doi_batch)  # Retry the same batch
    except requests.RequestException as e:
        return f"Request failed: {e}", f"Request failed: {e}"

    return f"Response status code: {response.status_code}", f"Response status code: {response.status_code}"

start_time = time.time()
pmid = {} 
no_pmid = []

def process_batch(b):
    return fetch_ids_batch(b)  # Returns (pmid_dict, no_pmid_list)

with ThreadPoolExecutor(max_workers = par) as executor:
    results = list(executor.map(process_batch, batches))

# Aggregate results
for pmid_dict, no_pmid_list in results:
    pmid.update(pmid_dict) 
    no_pmid.extend(no_pmid_list) 

print(f"Completed fetching pmids in {round(time.time() - start_time, 2)} seconds.")
# Out:
# Completed fetching pmids in 0.32 seconds.

# %%
print(len(pmid) )
print(len(no_pmid))
dico = dict(islice(pmid.items(), 80))
lis = no_pmid[0:30]
#print(lis)
#lis = list(batched(pmid.items(), bs))
#print(lis)
# Out:
# 19
# 21

# %% [markdown]
# # **Extract Abstract from PMC**
# 1. Using the pmids in the dict
# 2. Using epost for bulk queries

# %%
def get_pubmed_abstracts_bulk(pmid_dict):
    """
    Fetch abstracts in bulk using epost + efetch while keeping DOI keys.
    Returns: 
        - dict {DOI: Abstract}
        - DataFrame with DOI, Abstract
    """
    # Extract PMIDs
    pmid_list = list(pmid_dict.values())

    # epost to store PMIDs up to 10 000 at once
    epost_url = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/epost.fcgi"
    epost_params = {"db": "pubmed", "id": ",".join(pmid_list)}
    
    epost_response = requests.post(epost_url, data=epost_params, timeout=10)
    epost_response.raise_for_status()

    # Extract WebEnv & QueryKey
    root = ET.fromstring(epost_response.text)
    webenv = root.find("./WebEnv").text
    query_key = root.find("./QueryKey").text

    # efetch to retrieve abstracts
    efetch_url = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi"
    efetch_params = {
        "db": "pubmed",
        "query_key": query_key,
        "WebEnv": webenv,
        "retmode": "xml",
        "rettype": "abstract"
    }
    
    efetch_response = requests.get(efetch_url, params=efetch_params, timeout=10)
    efetch_response.raise_for_status()
    
    # Parse XML to extract abstracts
    root = ET.fromstring(efetch_response.text)
    abstracts = {}

    for article in root.findall(".//PubmedArticle"):
        pmid = article.find(".//PMID").text
        abstract_element = article.find(".//AbstractText")
        abstract_text = abstract_element.text if abstract_element is not None else "No abstract found"

        # Find corresponding DOI
        doi = next((k for k, v in pmid_dict.items() if v == pmid), None)
        if doi:
            abstracts[doi] = abstract_text

    # Convert to DataFrame
    df = pd.DataFrame(abstracts.items(), columns=["DOI", "Abstract"])
    
    return df

  # Add thousands of PMIDs here
start_time = time.time()
abstracts_df = get_pubmed_abstracts_bulk(pmid)
print(f"Completed in {round(time.time() - start_time, 2)} seconds.")

# Output as dictionary
#print(abstracts_dict)
# Out:
# Completed in 1.29 seconds.

# %%
# Output as DataFrame
display(abstracts_df)
#a = pd.DataFrame(list(ab.items()), columns=['DOI', 'Abstract'])
#display(a[a['Abstract'].str.split().str.len() > 4])
#display(a[a['Abstract'] == 'Error: HTTP 429'])
pmc_abstracts = pmc_citations_df.merge(abstracts_df, on='DOI', how='left')
display(pmc_abstracts)
# Out:
#                               DOI  \
# 0              10.3390/ma12213602
# 1            10.1155/2021/4105853
# 2              10.1039/d0ra06251k
# 3      10.1038/s41598-022-07674-7
# 4            10.3390/nano10091763
# 5       10.1049/iet-nbt.2018.5386
# 6              10.1039/d0ra07861a
# 7            10.3390/foods9020151
# 8   10.1016/S0140-6736(21)02724-0
# 9            10.3390/ijms22137202
# 10       10.3389/fmicb.2016.01831
# 11     10.1016/j.jfda.2017.07.005
# 12             10.1039/d1ra01256h
# 13           10.1155/2018/7879403
# 14           10.3390/nano10102082
# 15           10.3390/ijms23010026
# 16  10.1080/08820139.2020.1776724
# 17           10.1128/AAC.01106-08
# 18     10.1186/s11671-021-03547-6
#
#                                              Abstract
# 0   Nanoparticles play a significant role in vario...
# 1   Here presented a quick and easy synthesis of c...
# 2                                              The Fe
# 3   In this project, the new catalyst copper defin...
# 4   Currently, metal nanoparticles have varied use...
# 5   For being applied in medicine as therapeutic a...
# 6   The increasing knowledge on health benefit pro...
# 7                                         Mealworms (
# 8   Antimicrobial resistance (AMR) poses a major t...
# 9   Silver nanoparticles (AgNPs) have been imposed...
# 10  Multidrug resistance of the pathogenic microor...
# 11  Rice husk extract, obtained using acid and alk...
# 12  A heterogeneous, magnetically recoverable nano...
# 13  The spread of infectious diseases and the incr...
# 14                           An endophytic strain of
# 15  According to the World Health Organization rep...
# 16  Background Enthusiasm for the use of metal nan...
# 17  Silver nanoparticles, as well as antimicrobial...
# 18  The present study is concerned with evaluating...
#                     Citing DOI Citation ID  \
# 0   10.1038/s41598-023-47358-4         CR5
# 1   10.1038/s41598-023-47358-4         CR7
# 2   10.1038/s41598-023-47358-4         CR8
# 3   10.1038/s41598-023-47358-4        CR13
# 4   10.1038/s41598-023-47358-4        CR15
# 5   10.1038/s41598-023-47358-4        CR16
# 6   10.1038/s41598-023-47358-4        CR18
# 7   10.1038/s41598-023-47358-4        CR19
# 8   10.1038/s41598-023-47358-4        CR21
# 9   10.1038/s41598-023-47358-4        CR23
# 10  10.1038/s41598-023-47358-4        CR24
# 11  10.1038/s41598-023-47358-4        CR29
# 12  10.1038/s41598-023-47358-4        CR30
# 13  10.1038/s41598-023-47358-4        CR33
# 14  10.1038/s41598-023-47358-4        CR37
# 15  10.1038/s41598-023-47358-4        CR38
# 16  10.1038/s41598-023-47358-4        CR39
# 17  10.1038/s41598-023-47358-4        CR41
# 18  10.1038/s41598-023-47358-4        CR42
# 19  10.1038/s41598-023-47358-4        CR43
# 20  10.1038/s41598-023-47358-4        CR45
# 21  10.1038/s41598-023-47358-4        CR46
# 22  10.1038/s41598-023-47358-4        CR47
# 23  10.1038/s41598-023-47358-4        CR48
# 24  10.1038/s41598-023-47358-4        CR49
# 25  10.1038/s41598-023-47358-4        CR50
# 26  10.1038/s41598-023-47358-4        CR51
# 27  10.1038/s41598-023-47358-4        CR52
# 28  10.1038/s41598-023-47358-4        CR63
# 29  10.1038/s41598-023-47358-4        CR64
# 30  10.1038/s41598-023-47358-4        CR66
# 31  10.1038/s41598-023-47358-4        CR68
# 32  10.1038/s41598-023-47358-4        CR70
# 33  10.1038/s41598-023-47358-4        CR71
# 34  10.1038/s41598-023-47358-4        CR72
# 35  10.1038/s41598-023-47358-4        CR73
# 36  10.1038/s41598-023-47358-4        CR70
# 37  10.1038/s41598-023-47358-4        CR74
# 38  10.1038/s41598-023-47358-4        CR75
# 39  10.1038/s41598-023-47358-4        CR76
# 40  10.1038/s41598-023-47358-4        CR77
#
#                                      Citation Context  \
# 0   Due to increasing environmental problems, find...
# 1   Due to increasing environmental problems, find...
# 2   For this purpose, economic and biocompatible a...
# 3   Nanotechnology is one of the newest and most e...
# 4   Nanotechnology is one of the newest and most e...
# 5   The utilization of biologic materials such as ...
# 6   The utilization of biologic materials such as ...
# 7   These eco-friendly condition are more efficien...
# 8   Green methods may synthesize NPs with better s...
# 9   The reduction of metal ions using plant extrac...
# 10  It is suggested that water-soluble plant metab...
# 11  It is suggested that water-soluble plant metab...
# 12  The synthesized metallic NPs have unique optic...
# 13  The synthesized metallic NPs have unique optic...
# 14  Synergistic biological effects may be observed...
# 15  Purple cabbage  ( Brassica oleracea var.capita...
# 16  rubra ) is one of the plants that can be used ...
# 17  It is a herbaceous, two-year and dicotyledonou...
# 18  It is believed that glucosinolates, polyphenol...
# 19  It is considered as the best vegetable among  ...
# 20  It is considered as the best vegetable among  ...
# 21  Phenolic compounds are the main antioxidants i...
# 22  Among polyphenolic compounds, anthocyanins in ...
# 23  In addition to preventive measures, new antimi...
# 24  In addition to preventive measures, new antimi...
# 25  Ag and Cu sources such as metal NPs and comple...
# 26  Ag and Cu sources such as metal NPs and comple...
# 27  To conduct the experiment, 70 g of chopped  pu...
# 28  Phenolic compounds, especially anthocyanins, i...
# 29        The FT-IR spectrum of the Schiff base (Fig.
# 30  2 a) shows stretching vibrations of the O–H gr...
# 31  2 a) shows stretching vibrations of the O–H gr...
# 32  The peak in the region of 245 nm corresponds t...
# 33  The surface plasmon resonance  bands in the ra...
# 34  The peak related to Cu NPs is also observed ar...
# 35  2θ values of 10–80° were obtained for Cu and A...
# 36  The pattern revealed the diffraction peaks of ...
# 37                                   aureus  strains.
# 38  Polymyxin B peptide is a naturally occurring a...
# 39  Polymyxin B peptide is a naturally occurring a...
# 40             against antibiotic-resistant bacteria.
#
#                                           Cited Title  \
# 0              Metal nanoparticles as green catalysts
# 1   Fe(III)-salen complex supported on dendrimer f...
# 2   Nickel nanoparticles adorned on magnetized cel...
# 3   A comprehensive review on green synthesis of n...
# 4         Biosynthesis of organic nanocomposite using
# 5                 Design and synthesis of magnetic Fe
# 6   New Acetamidine Cu(II) Schiff base complex sup...
# 7   Green synthesis of nanoparticles using plant e...
# 8   Bioinspired and green synthesis of nanoparticl...
# 9   Green synthesis of gold and silver nanoparticl...
# 10  Metal nanoparticles synthesis through natural ...
# 11  Cu/cellulose-modified magnetite nanocomposites...
# 12  A review on biosynthesis of metal nanoparticle...
# 13  Green synthesis of Cu nanoparticles using Curc...
# 14  Current trends and challenges in the synthesis...
# 15  Antibacterial activity of nanocomposites of si...
# 16                     Encapsulation of red cabbage (
# 17  Comparative study of young shoots and the matu...
# 18  Enhancement of phenolic and flavonoids compoun...
# 19  Red cabbage anthocyanins: Profile, isolation, ...
# 20  Growth performance and nutrient composition of...
# 21  Green synthesis of silver nanoparticles from a...
# 22  Global burden of bacterial antimicrobial resis...
# 23  Silver nanoparticles and their antibacterial a...
# 24                         Antibacterial effect of Cu
# 25  Mechanistic basis of antimicrobial actions of ...
# 26             Study on behaviour and mechanism of Cu
# 27  Comparative study on the extraction and quanti...
# 28  Silver nanoparticle biosynthesis by using phen...
# 29  Synthesis of cellulose nanofibers-based ImSalo...
# 30  Synthesis, characterization and cytotoxicity e...
# 31  Simple synthesis of the novel Cu-MOF catalysts...
# 32  Biogenic synthesis of copper and silver nanopa...
# 33  Bactericidal and in-vitro cytotoxic efficacy o...
# 34  Determination of total phenolic content in oli...
# 35  Biosynthesis, characterization and antimicrobi...
# 36  Biogenic synthesis of copper and silver nanopa...
# 37                        Antibacterial therapy by Ag
# 38      Metal nanoparticles in infection and immunity
# 39  Synergistic Interaction between Silver Nanopar...
# 40  Development of multi-concentration Cu: Ag bime...
#
#                                   DOI  \
# 0                  10.3390/ma12213602
# 1          10.1016/j.jpcs.2020.109642
# 2          10.1007/s10570-022-04823-z
# 3       10.1016/j.jclepro.2020.122880
# 4                10.1155/2021/4105853
# 5                  10.1039/D0RA06251K
# 6          10.1038/s41598-022-07674-7
# 7          10.1007/s10311-020-01074-x
# 8          10.1016/j.jscs.2021.101304
# 9                10.3390/nano10091763
# 10          10.1049/iet-nbt.2018.5386
# 11          10.1016/j.scp.2022.100672
# 12  10.1016/j.chemosphere.2020.128580
# 13       10.1016/j.matlet.2019.126813
# 14      10.1016/j.carbpol.2021.117904
# 15       10.1016/j.actbio.2009.02.003
# 16       10.1590/S1516-89132015060226
# 17                 10.1039/D0RA07861A
# 18      10.1080/14786419.2018.1508145
# 19      10.1016/j.foodres.2012.12.015
# 20               10.3390/foods9020151
# 21    10.1088/1742-6596/2274/1/012001
# 22      10.1016/S0140-6736(21)02724-0
# 23               10.3390/ijms22137202
# 24       10.1016/j.vetmic.2005.04.021
# 25           10.3389/fmicb.2016.01831
# 26     10.1179/1753555714Y.0000000236
# 27             10.12944/CRNFSJ.7.3.08
# 28         10.1016/j.jfda.2017.07.005
# 29       10.1016/j.microc.2022.108368
# 30                 10.1039/D1RA01256H
# 31                   10.1002/aoc.5965
# 32               10.1155/2018/7879403
# 33               10.3390/nano10102082
# 34          10.1007/s12161-012-9379-5
# 35          10.1007/s13204-013-0233-x
# 36               10.1155/2018/7879403
# 37               10.3390/ijms23010026
# 38      10.1080/08820139.2020.1776724
# 39               10.1128/AAC.01106-08
# 40         10.1186/s11671-021-03547-6
#
#                                              Abstract
# 0   Nanoparticles play a significant role in vario...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   Here presented a quick and easy synthesis of c...
# 5                                                 NaN
# 6   In this project, the new catalyst copper defin...
# 7                                                 NaN
# 8                                                 NaN
# 9   Currently, metal nanoparticles have varied use...
# 10  For being applied in medicine as therapeutic a...
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                        Mealworms (
# 21                                                NaN
# 22  Antimicrobial resistance (AMR) poses a major t...
# 23  Silver nanoparticles (AgNPs) have been imposed...
# 24                                                NaN
# 25  Multidrug resistance of the pathogenic microor...
# 26                                                NaN
# 27                                                NaN
# 28  Rice husk extract, obtained using acid and alk...
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32  The spread of infectious diseases and the incr...
# 33                           An endophytic strain of
# 34                                                NaN
# 35                                                NaN
# 36  The spread of infectious diseases and the incr...
# 37  According to the World Health Organization rep...
# 38  Background Enthusiasm for the use of metal nan...
# 39  Silver nanoparticles, as well as antimicrobial...
# 40  The present study is concerned with evaluating...

# %% [markdown]
# # **Extract Abstract from Crossref**
# 1. Using the dois in the list

# %%
USER_AGENT = f"YourAppName/1.0 (mailto:{mail})"
CROSSREF_URL = "https://api.crossref.org/works/"

HEADERS = {"User-Agent": USER_AGENT}
MAX_WORKERS = 5  # Number of parallel requests
RETRIES = 3  # Max retry attempts

# %%
failed_dois = []

def get_crossref_metadata(doi):
    """Fetch metadata from CrossRef for a single DOI."""
    url = f"{CROSSREF_URL}{doi}"
    
    try:
        response = requests.get(url, headers=HEADERS, timeout = 25)

        if response.status_code == 200:
            data = response.json().get("message", {})
            return {
                "DOI": doi,
                "Publisher": data.get("publisher", "Unknown Publisher"),
                "Journal": data.get("container-title", ["Unknown Journal"])[0],
                "Abstract": data.get("abstract", "No abstract found"),
                "Journal Article": "Yes" if data.get("type") == "journal-article" else "No",
                "Error": None,
            }

        elif response.status_code == 404:
            return {"DOI": doi, "Error": "DOI Not Found"}

        else:
            failed_dois.append(doi)  # Save DOI for retry
            return {"DOI": doi, "Error": f"HTTP {response.status_code}"}

    except requests.RequestException as e:
        failed_dois.append(doi)  # Save DOI for retry
        return {"DOI": doi, "Error": str(e)}

def fetch_metadata_parallel(doi_list):
    """Fetch metadata for a list of DOIs in parallel using ThreadPoolExecutor."""
    metadata_list = []
    
    with ThreadPoolExecutor(max_workers=5) as executor:
        futures = {executor.submit(get_crossref_metadata, doi): doi for doi in doi_list}

        for future in tqdm(as_completed(futures), total=len(doi_list), desc="Fetching Metadata"):
            metadata_list.append(future.result())

    return metadata_list

start_time = time.time()
metadata_results = fetch_metadata_parallel(lis)
metadata_df = pd.DataFrame(metadata_results)
print(f"Completed in {round(time.time() - start_time, 2)} seconds.")
display(metadata_df)

if failed_dois:
    with open("failed_dois.txt", "w") as f:
        for doi in failed_dois:
            f.write(doi + "\n")
    print(f"{len(failed_dois)} requests failed. Saved to failed_dois.txt for retry.")
# Out:
# Fetching Metadata: 100%|████████████████████████| 21/21 [00:01<00:00, 10.63it/s]
# Completed in 1.99 seconds.
#                                   DOI  \
# 0       10.1016/j.foodres.2012.12.015
# 1      10.1179/1753555714Y.0000000236
# 2          10.1007/s10570-022-04823-z
# 3       10.1080/14786419.2018.1508145
# 4     10.1088/1742-6596/2274/1/012001
# 5          10.1007/s10311-020-01074-x
# 6           10.1016/j.scp.2022.100672
# 7        10.1016/j.actbio.2009.02.003
# 8   10.1016/j.chemosphere.2020.128580
# 9       10.1016/j.jclepro.2020.122880
# 10         10.1016/j.jpcs.2020.109642
# 11          10.1007/s12161-012-9379-5
# 12       10.1016/j.vetmic.2005.04.021
# 13       10.1016/j.microc.2022.108368
# 14             10.12944/CRNFSJ.7.3.08
# 15       10.1016/j.matlet.2019.126813
# 16          10.1007/s13204-013-0233-x
# 17                   10.1002/aoc.5965
# 18       10.1590/S1516-89132015060226
# 19         10.1016/j.jscs.2021.101304
# 20      10.1016/j.carbpol.2021.117904
#
#                                   Publisher  \
# 0                               Elsevier BV
# 1                        Informa UK Limited
# 2   Springer Science and Business Media LLC
# 3                        Informa UK Limited
# 4                            IOP Publishing
# 5   Springer Science and Business Media LLC
# 6                               Elsevier BV
# 7                               Elsevier BV
# 8                               Elsevier BV
# 9                               Elsevier BV
# 10                              Elsevier BV
# 11  Springer Science and Business Media LLC
# 12                              Elsevier BV
# 13                              Elsevier BV
# 14               Enviro Research Publishers
# 15                              Elsevier BV
# 16  Springer Science and Business Media LLC
# 17                                    Wiley
# 18                      FapUNIFESP (SciELO)
# 19  Springer Science and Business Media LLC
# 20                              Elsevier BV
#
#                                               Journal  \
# 0                         Food Research International
# 1                                Materials Technology
# 2                                           Cellulose
# 3                            Natural Product Research
# 4               Journal of Physics: Conference Series
# 5                     Environmental Chemistry Letters
# 6                  Sustainable Chemistry and Pharmacy
# 7                                  Acta Biomaterialia
# 8                                         Chemosphere
# 9                       Journal of Cleaner Production
# 10         Journal of Physics and Chemistry of Solids
# 11                            Food Analytical Methods
# 12                            Veterinary Microbiology
# 13                              Microchemical Journal
# 14  Current Research in Nutrition and Food Science...
# 15                                  Materials Letters
# 16                                Applied Nanoscience
# 17                   Applied Organometallic Chemistry
# 18       Brazilian Archives of Biology and Technology
# 19                  Journal of Saudi Chemical Society
# 20                              Carbohydrate Polymers
#
#                                              Abstract Journal Article Error
# 0                                   No abstract found             Yes  None
# 1                                   No abstract found             Yes  None
# 2                                   No abstract found             Yes  None
# 3                                   No abstract found             Yes  None
# 4   <jats:title>Abstract</jats:title><jats:p>We ex...             Yes  None
# 5                                   No abstract found             Yes  None
# 6                                   No abstract found             Yes  None
# 7                                   No abstract found             Yes  None
# 8                                   No abstract found             Yes  None
# 9                                   No abstract found             Yes  None
# 10                                  No abstract found             Yes  None
# 11                                  No abstract found             Yes  None
# 12                                  No abstract found             Yes  None
# 13                                  No abstract found             Yes  None
# 14  <jats:p>Citrus processing industry generates t...             Yes  None
# 15                                  No abstract found             Yes  None
# 16                                  No abstract found             Yes  None
# 17  <jats:p>A novel porous metal–organic framework...             Yes  None
# 18                                  No abstract found             Yes  None
# 19                                  No abstract found             Yes  None
# 20                                  No abstract found             Yes  None
